# %%
from sympy import gcd, mod_inverse

def extended_gcd(a, b):
    if a == 0:
        return b, 0, 1
    else:
        gcd, x1, y1 = extended_gcd(b % a, a)
        x = y1 - (b // a) * x1
        y = x1
        return gcd, x, y

# Given values
n = int("...")
e1 = int("")
e2 = int("")
c1 = int("...", 16)
c2 = int("...", 16)

# Using the Extended Euclidean Algorithm to find x and y
gcd_val, x, y = extended_gcd(e1, e2)

# Make sure gcd is 1
if gcd_val != 1:
    raise ValueError("gcd(e1, e2) is not 1, common modulus attack cannot be applied")

# Adjust x and y if necessary
if x < 0:
    x = -x
    c1 = mod_inverse(c1, n)
if y < 0:
    y = -y
    c2 = mod_inverse(c2, n)

# Calculate M
M = (pow(c1, x, n) * pow(c2, y, n)) % n

print("Recovered message M:", M)
print("M in hex:", hex(M))
# Out:
# Recovered message M: ...
# M in hex: ...

# %%
from sympy import mod_inverse

# %%
print(mod_inverse(3186145257986644963713639904829242332,340282366920938463463374607431768211827))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(mod_inverse(3186145257986644963713639904829242332,340282366920938463463374607431768211827))
#
# File ~\anaconda3\Lib\site-packages\sympy\core\numbers.py:552, in mod_inverse(a, m)
#     550         c = 1/a
#     551 if c is None:
# --> 552     raise ValueError('inverse of %s (mod %s) does not exist' % (a, m))
#     553 return c
#
# ValueError: inverse of 3186145257986644963713639904829242332 (mod 340282366920938463463374607431768211827) does not exist

# %%
from sympy import mod_inverse

# Extended Euclidean Algorithm to find x and y
def extended_gcd(a, b):
    if a == 0:
        return b, 0, 1
    else:
        gcd, x1, y1 = extended_gcd(b % a, a)
        x = y1 - (b // a) * x1
        y = x1
        return gcd, x, y

# Given values
n = int("...")
e1 = int("")
e2 = int("")
c1 = int("...", 16)
c2 = int("...", 16)

# Using the Extended Euclidean Algorithm to find x and y
gcd_val, x, y = extended_gcd(e1, e2)

# Make sure gcd is 1
if gcd_val != 1:
    raise ValueError("gcd(e1, e2) is not 1, common modulus attack cannot be applied")

# Adjust x and y if necessary
if x < 0:
    x = -x
    c1 = mod_inverse(c1, n)
if y < 0:
    y = -y
    c2 = mod_inverse(c2, n)

# Calculate M using pow for modular exponentiation
M = (pow(c1, x, n) * pow(c2, y, n)) % n

print("Recovered message M:", M)
print("M in hex:", hex(M))
# Out:
# Recovered message M: ...
# M in hex: ...

# %%
from sympy import mod_inverse

# Extended Euclidean Algorithm to find x and y
def extended_gcd(a, b):
    if a == 0:
        return b, 0, 1
    else:
        gcd, x1, y1 = extended_gcd(b % a, a)
        x = y1 - (b // a) * x1
        y = x1
        return gcd, x, y

# Given values
n1 = int("...");
e1 = int("");
n2 = int("...");
e2 = int("");
c1 = int("...");
c2 = int("...");

# Using the Extended Euclidean Algorithm to find x and y
gcd_val, x, y = extended_gcd(e1, e2)

# Make sure gcd is 1
if gcd_val != 1:
    raise ValueError("gcd(e1, e2) is not 1, common modulus attack cannot be applied")

# Adjust x and y if necessary
if x < 0:
    x = -x
    c1 = mod_inverse(c1, n)
if y < 0:
    y = -y
    c2 = mod_inverse(c2, n)

# Calculate M using pow for modular exponentiation
M = (pow(c1, x, n) * pow(c2, y, n)) % n

print("Recovered message M:", M)
print("M in hex:", hex(M))
# Out:
# Recovered message M: 73655
# M in hex: 0x11fb7
